# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You are advising the mayor of a mid-sized coastal city (population 500,000) whose central business district and several low-income neighborhoods lie in the current 100-year floodplain. The city has $600M in capital available for the next decade, municipal assets at risk valued at ~$20B, and an annual city budget of $2B. Sea-level-rise projections for the city are a median of ~0.6 m by 2050 and ~1.2 m by 2100, with a plausible upper tail to ~1.5 m by 2100; storm surge intensity and frequency are increasing. The mayor must choose among: (A) building a large seawall to protect the CBD and waterfront, (B) planning and funding phased managed retreat from the most vulnerable areas over ~30 years, (C) implementing distributed “green infrastructure” and elevation/flood-proofing with selective small barriers, or (D) a hybrid strategy. Which option or combination do you recommend, and why? In your answer, provide (1) a clear recommendation and the principal rationale; (2) the key assumptions you are making and their uncertainties (give qualitative probabilities where useful); (3) an estimated 10-year and 30-year timeline with rough cost ranges and plausible funding strategies; (4) an analysis of distributional impacts on low-income and vulnerable residents and concrete mitigation measures to ensure equity; (5) specific monitoring indicators and decision “triggers” (with thresholds) that would prompt changing course; (6) the top three risks or failure modes for your recommendation and mitigations for each; (7) three prioritized short-term actions (0–5 years) and one pilot project designed to reduce critical uncertainty; and (8) a concise statement of your confidence in the recommendation (low/medium/high) and which new evidence or events would most likely change it.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a structured policy advisory tailored to a mid-sized coastal city facing significant flood and sea-level-rise risk. It blends engineering, nature-based solutions, and orderly planning for managed retreat, with equity at the center.
#
# 1) Clear recommendation and principal rationale
# - Recommendation: Adopt a hybrid strategy (Option D) that combines:
#   - Green/soft infrastructure and elevation-focused protections for the most critical assets and neighborhoods (Option C components applied citywide where feasible),
#   - Selective small-scale flood barriers and barriers around key chokepoints (light gray/gray infrastructure),
#   - A disciplined, time-phased plan for managed retreat and buyouts in the most vulnerable neighborhoods, with preserves for growth on higher ground and replacement housing in safe areas (Option B components applied selectively and in staged fashion),
#   - A potential larger-scale waterfront protection only if risk, demand, and funding justify it later (scenario-responsive siting, not a fixed upfront seawall).
# - Why this combination:
#   - Sea-level rise is ongoing and uncertain (0.6 m by 2050, ~1.2 m by 2100 with tail risk), while storm surge is intensifying. A single “wall” solution is risky, unaffordable at scale, and creates equity and maintenance challenges; wholesale retreat is politically difficult and costly if pursued too aggressively too early. A hybrid approach spreads risk, preserves affordable options for low-income residents, protects critical assets, and builds adaptive capacity as new data arrives.
#   - Green infrastructure provides co-benefits (cooling, urban heat mitigation, water quality, recreation) and is generally more adaptable to changing conditions. Elevation and selective barriers protect critical nodes (schools, hospitals, transit nodes, emergency services). Phased managed retreat reduces long-term exposure and public liability while enabling new affordable housing and economic opportunities in safer areas. A flexible plan survives many futures and is more defensible to funders and the public.
#
# 2) Key assumptions and uncertainties (qualitative probabilities)
# - Climate and hazards
#   - SLR: Median projections are ~0.6 m (2050) and ~1.2 m (2100); upper tail could reach ~1.5 m by 2100. Probability of higher-than-median outcomes increases the risk of coastal inundation; assume a moderate-to-high likelihood that some areas will experience flood depths beyond today’s tolerances after 2050. Probability of marginal benefits from adaptation depends on local hydrodynamics and landform.
#   - Storm surge/frequency: Increasing; probability of more frequent, higher surge events during extreme rainfall/frost events is high.
# - Exposure and equity
#   - CBD and several low-income neighborhoods are in the current 100-year floodplain; risk is persistent and disproportionally borne by low-income households and small businesses. Probability that a spike in flood risk disproportionately affects vulnerable groups is high.
# - Financial and political
#   - Capital available: ~$600M over 10 years; annual budget ~$2B; asset at risk ~$20B. Probability of additional federal/state funding is moderate but uncertain; debt capacity and political will will shape timing.
# - Technology and maintenance
#   - Green infrastructure performance is plausible but maintenance-heavy; success depends on local governance, staffing, and resident engagement. Probability of underinvestment in maintenance is a risk.
# - Social tolerance and displacement
#   - Community acceptance of managed retreat varies; probability of resistance in some neighborhoods is nontrivial. Targeted buyouts and replacement housing programs will require careful design and transparency.
#
# 3) 10-year and 30-year timeline, rough costs, and funding strategies
# - 10-year plan (0–10 years)
#   - Core actions:
#     - Implement a citywide resilience program with a governance unit (resilience/climate office).
#     - Deploy a broad green infrastructure program (green streets, bioswales, permeable pavements, rain gardens) in selected high-priority neighborhoods; elevate or flood-proof critical facilities (schools, clinics, emergency operations centers, water/waste facilities).
#     - Install selective small-scale barriers and low-cost gray protections around critical bottlenecks (e.g., grade-separated crossings, floodgates at key drainage inlets, temporary/permanent barrier improvements where cost-effective).
#     - Begin an equitable retreat-readiness pathway: establish a buyout fund, target a limited number of households for voluntary relocation in the most exposed zones, and begin land-use planning for safe, affordable replacement housing on higher ground.
#     - Initiate a robust flood-risk and asset map refresh with LIDAR, hydrodynamic modeling, and community risk perception surveys.
#   - Rough cost range (10-year window):
#     - Green/blue infrastructure, elevation of assets, small barriers: $450–$750M.
#     - Buyout funding and relocation readiness for a subset of the most vulnerable parcels: $100–$250M (initial tranche; scalable to year 10 depending on risk).
#     - Planning, design, land acquisition, project management, resilience office operations: $50–$100M.
#     - Total 10-year capital needs (rough): $600M. This aligns with the city’s 10-year capital envelope and leverages some federal/state funding and bonds.
#   - Funding strategy:
#     - A mix of municipal bonds (general obligation or revenue-backed), state/federal resilience grants, community development finance locally (CDFI-backed), and public-private partnerships where applicable.
#     - Establish a resilience fund/line of credit as a contingency for overruns.
#     - Seek federal/state programs focused on disaster resilience, climate adaptation, and buyouts; pursue insurance-related resilience grant programs where available.
# - 30-year horizon (10–30 years)
#   - Actions:
#     - Scale green infrastructure and flood-proofing citywide, prioritizing neighborhoods with remaining exposure.
#     - Expand managed retreat in a phased, consent-based manner in the most exposed areas; create replacement housing and economic opportunities in safer zones; implement land-use changes to prevent new construction in high-risk areas.
#     - Reassess the value and role of a waterfront protection feature after monitoring, data, and risk appetite: consider a targeted seawall or barrier around critical corridors if conditions justify it and funding becomes available, but only with a carefully justified cost-benefit and equity safeguards.
#   - Rough cost range (30-year program beyond year 10):
#     - Expanded green infrastructure and elevation: $1–2.5B (over 20 years), depending on scale and communities engaged.
#     - Managed retreat and housing replacement: $1–3B (depending on pace, land costs, and housing stock policy; could be higher if large-scale buyouts occur).
#     - Seawall/barrier (if triggered later): $1–3B depending on length, height, and protection level required.
#     - Total 30-year program (incremental, if fully pursued as described): potentially $2–5B+ beyond year 10, highly contingent on risk trajectory and funding success.
#   - Funding strategy:
#     - Expanded state/federal grants tied to resilience, hazard mitigation, and climate adaptation.
#     - Long-term municipal bonds or value capture financing for area-specific protections.
#     - New housing trust funds and incentives to stimulate development on higher ground; state-backed affordable housing programs to finance replacement housing in retreat zones.
#     - Public-private partnerships and performance-based contracts for maintenance of green infrastructure.
# - Overall perspective
#   - The city should begin now with 0–10-year investments that demonstrate measurable risk reduction, track costs, and build trust with residents. The 10–20 year window should show performance data to justify ongoing, scaled retreat and any potential waterfront protection decisions. Keep the option of a waterfront barrier as a late-stage, data-driven decision, not as a default.
#
# 4) Distributional impacts on low-income and vulnerable residents and equity measures
# - Impacts to watch
#   - Without safeguards, retreat could cluster in ways that displace low-income households and disrupt existing communities, jobs, and access to services.
#   - Green infrastructure investments can benefit low-income neighborhoods through flood reduction and health co-benefits but require ongoing maintenance commitments to avoid neglect.
# - Mitigation measures
#   - Equity-centered design: prioritize protection of high-risk, low-income neighborhoods with early-stage green infrastructure and non-displacing protections; ensure essential services remain accessible.
#   - Transparent, voluntary buyouts: use clear criteria, fair appraisals, and predictable timelines; allow local hire and contractor preferences for residents.
#   - Replacement housing and mobility: create affordable housing options on higher ground with access to jobs, transit, and essential services; guarantee a right-to-return for displaced residents where feasible.
#   - Economic inclusion: require local hiring for resilience projects, support small and minority-owned businesses in flood-prone areas, and provide microgrants for home elevation and flood-proofing.
#   - Financial protections: offer property tax relief or subsidies for residents who participate in buyouts; provide temporary rental assistance and subsidies for displaced residents; maintain mental-health and community services during transition.
#   - Community engagement: continuous, accessible (multi-language) community engagement; involve residents in planning decisions to ensure culturally appropriate and acceptable solutions.
# - Concrete measures
#   - Set aside a minimum % of capital for affordable housing in retreat zones and for housing replacement on higher ground.
#   - Protect tenants with strong affordability covenants in replacement housing; ensure housing density and design accommodate families of varying sizes.
#   - Ensure critical services (water, health, emergency response) remain functional and accessible throughout retreat and adaptation phases.
#   - Create local job pipelines for resilience projects (construction, maintenance, planning, monitoring) to build community capacity and economic resilience.
#
# 5) Monitoring indicators and decision triggers (thresholds)
# - Hazard and exposure indicators
#   - Sea-level rise metrics: track observed vs. modeled SLR by neighborhood; trigger re-evaluation if observed rates exceed projections by >20% over a 5-year period.
#   - Flood depth/extent: monitor nuisance flooding frequency and depth in the CBD and low-income neighborhoods; trigger adaptive design modifications if flash or high-tide flooding exceeds X inches/depth for Y events per year over 3 consecutive years.
#   - Storm surge events: track frequency/intensity; trigger enhanced protective measures if surge events exceed forecasted baselines in consecutive seasons.
# - Infrastructure performance indicators
#   - Green infrastructure performance: measure runoff capture, water quality benefits, maintenance cost per area; trigger adjustments if capture is below target during a full-year monitoring period.
#   - Elevation and barrier performance: monitor structure integrity, closure times, maintenance needs; trigger upgrades if performance degrades or if there is repeated failure during events.
# - Social and equity indicators
#   - Displacement/relocation metrics: number of households in buyouts, time-to-move, access to replacement housing; trigger policy review if displacement exceeds planned thresholds or if community concerns rise sharply.
#   - Housing and economic outcomes: track affordable housing units created, job placement for residents in resilience projects, and changes in property values near protections; trigger rebalancing of investments if negative trends persist.
# - Financial indicators
#   - Cost overruns, funding gaps, and debt service: track against budget; trigger reallocation or additional funding strategies if overruns approach a predefined threshold (e.g., 20% over budget or 10% schedule slippage).
# - Data sources and governance
#   - Establish a resilient-data dashboard with quarterly reporting to the mayor and council; include community input mechanisms to ensure transparency.
#
# Decision triggers
# - If SLR/storm data indicate significantly higher risk than current plan (e.g., >20% higher water levels or higher frequency of severe surge within 5–10 years), accelerate targeted protections and accelerate retreat planning in vulnerable zones.
# - If funding prospects improve (state/federal grants, favorable treasury conditions) and risk-adjusted ROI remains favorable, scale up hybrid protections or accelerate buyouts where equity considerations are strongest.
# - If equity concerns rise due to displacement or loss of housing affordability, pause high-disruption moves and reallocate funds toward protection and affordable replacement housing closer to existing communities.
#
# 6) Top three risks or failure modes and mitigations
# - Risk 1: Underfunding or cost overruns; mitigation: rigorous, staged financing plan; reserve funds; flex in scope; pursue multiple funding streams (bonds, grants, public-private partnerships) and establish a contingency fund. Maintain transparent reporting and public accountability to preserve support.
# - Risk 2: Equity failures and community resistance to retreat; mitigation: invest early in inclusive planning; ensure consent-based buyouts with robust protections; provide strong replacement housing and job opportunities; implement tenant protections and rent subsidies; ensure ongoing community benefits from resilience investments.
# - Risk 3: Maintenance and performance gaps in green infrastructure; mitigation: build local capacity for operations and maintenance; adopt performance-based contracts; require maintenance funds and clear accountability; implement adaptive management to address climate variability.
# - Additional risk: Data uncertainty and political risk; mitigation: decision rules anchored in adaptive management, with defined triggers and rollback options; maintain flexibility to reallocate funds in response to new data or events.
#
# 7) Three prioritized short-term actions (0–5 years) and one pilot project to reduce critical uncertainty
# - Short-term actions (0–5 years)
#   - Action 1: Establish a dedicated resilience governance unit with a clear funding strategy, risk modeling capability, equity-focused design standards, and a detailed data dashboard for ongoing decision-making.
#   - Action 2: Implement 2–3 targeted green infrastructure pilots in high-risk, high-need neighborhoods (e.g., bioswales, permeable pavements, rain gardens, elevated walkways) and upgrade 2–3 critical facilities (schools, clinics, emergency operations) with flood-proofing and backup power. Begin resident outreach on retreat options, and set up a buyout assistance framework.
#   - Action 3: Create a phased, voluntary retreat-readiness plan for the most exposed neighborhoods, including a pilot buyout of a limited number of households, with replacement housing planning, and a local workforce development program to ensure residents can participate in resilience work.
# - Pilot project designed to reduce critical uncertainty
#   - Pilot Project: A 1–2 mile waterfront resilience corridor combining green-blue infrastructure with a modular, low-cost barrier at a critical inlet. This project would be designed as a controlled, data-rich test of:
#     - How green infrastructure reduces flood depth and frequency in a real neighborhood setting,
#     - The incremental cost and performance of low-cost barriers integrated with green systems,
#     - Social acceptability, maintenance needs, and job-creation potential for residents.
#   - Outcomes to measure in the pilot: flood reduction performance, maintenance costs, resident satisfaction, economic impact, and lessons for scaling the approach citywide.
#
# 8) Confidence statement and events that could change the recommendation
# - Confidence level: Medium to High
#   - Rationale: A hybrid approach provides a balanced, adaptable path that mitigates risk from multiple angles, aligns with equity goals, and leverages a broad range of funding opportunities. It also avoids the political and fiscal risks of a single heavy infrastructure push (like a city-wide seawall) or an overly rapid retreat entirely funded by the city.
# - What new evidence or events could most likely change the recommendation:
#   - Funding landscape: If federal/state resilience funding expands significantly or if a major public-private financing mechanism becomes available, a more protective waterfront barrier (or expanded full seawall) could become viable and attractive earlier than planned, potentially shifting more emphasis toward gray infrastructure.
#   - Risk realization: If observed watershed and coastal data indicate a more severe or earlier-than-expected flood regime (e.g., rapid SLR acceleration, higher storm surge frequency), the city might accelerate retreat in certain zones or scale up protection in critical corridors sooner.
#   - Equity and social response: If community engagement reveals widespread opposition to retreat or if displacement risks become politically unsustainable, the plan would need to adjust toward protection and incremental, voluntary retreat with stronger support measures.
#   - Infrastructure performance data: If pilots clearly demonstrate cost-effective flood reduction and scalable maintenance, the city may accelerate green infrastructure deployment and reduce the need for expensive hard barriers.
#
# Notes for executive decision-makers
# - This plan intentionally prioritizes a flexible, equitable, and data-driven approach. It preserves options for scalable protection, prioritizes protecting essential assets, and uses retreat strategically where the risk is highest and the costs are manageable.
# - The equity lens is non-negotiable: protections, housing, and economic opportunities must be accessible to low-income residents who are most exposed.
# - Governance, public engagement, and robust data are essential to keep this plan adaptive and credible to residents, funders, and stakeholders.
#
# If you’d like, I can translate this into a more formal policy memo with a one-page executive summary, a 2–3 page implementation plan for the next 12–18 months, and a high-level budget and financing outline tailored to your city’s specific budgetary and political context.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
# response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
# answer = response.content[0].text

# display(Markdown(answer))
# competitors.append(model_name)
# answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Recommendation:** A hybrid strategy incorporating aspects of options B, C, and D.
#
# **Principal Rationale:**
#
# 1. **Mitigate flood risk while considering long-term resilience**: The hybrid approach will combine the benefits of phased managed retreat with targeted green infrastructure and elevation/flood-proofing measures to protect vulnerable areas. This multi-faceted strategy acknowledges the ongoing threat of sea-level rise and storm surge enhancements while allowing for adaptive management in response to changing conditions.
# 2. **Optimize resource allocation**: By combining elements from each option, the hybrid approach utilizes a mix of short-term (A), mid-term (C), and long-term (B) solutions, ensuring that capital is allocated efficiently across different scales and timeframes.
# 3. **Address distributional impacts and equity concerns**: The hybrid strategy prioritizes inclusive adaptation, incorporating measures designed to support vulnerable populations and ensure equitable outcomes.
#
# **Key Assumptions and Uncertainties:**
#
# 1. Sea-level rise (SLR) projections are reliable (~70% certainty), but some variability exists (20%.
# 2. Projected storm surge intensity and frequency are plausible within current projections (~50% confidence).
# 3. Adaptive management effectiveness in response to changing conditions is uncertain (~30% probability).

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'llama3.2']
# ['Below is a structured policy advisory tailored to a mid-sized coastal city facing significant flood and sea-level-rise risk. It blends engineering, nature-based solutions, and orderly planning for managed retreat, with equity at the center.\n\n1) Clear recommendation and principal rationale\n- Recommendation: Adopt a hybrid strategy (Option D) that combines: \n  - Green/soft infrastructure and elevation-focused protections for the most critical assets and neighborhoods (Option C components applied citywide where feasible), \n  - Selective small-scale flood barriers and barriers around key chokepoints (light gray/gray infrastructure),\n  - A disciplined, time-phased plan for managed retreat and buyouts in the most vulnerable neighborhoods, with preserves for growth on higher ground and replacement housing in safe areas (Option B components applied selectively and in staged fashion),\n  - A potential larger-scale waterfront protection only if risk, demand, and funding justify it later (scenario-responsive siting, not a fixed upfront seawall).\n- Why this combination: \n  - Sea-level rise is ongoing and uncertain (0.6 m by 2050, ~1.2 m by 2100 with tail risk), while storm surge is intensifying. A single “wall” solution is risky, unaffordable at scale, and creates equity and maintenance challenges; wholesale retreat is politically difficult and costly if pursued too aggressively too early. A hybrid approach spreads risk, preserves affordable options for low-income residents, protects critical assets, and builds adaptive capacity as new data arrives.\n  - Green infrastructure provides co-benefits (cooling, urban heat mitigation, water quality, recreation) and is generally more adaptable to changing conditions. Elevation and selective barriers protect critical nodes (schools, hospitals, transit nodes, emergency services). Phased managed retreat reduces long-term exposure and public liability while enabling new affordable housing and economic opportunities in safer areas. A flexible plan survives many futures and is more defensible to funders and the public.\n\n2) Key assumptions and uncertainties (qualitative probabilities)\n- Climate and hazards\n  - SLR: Median projections are ~0.6 m (2050) and ~1.2 m (2100); upper tail could reach ~1.5 m by 2100. Probability of higher-than-median outcomes increases the risk of coastal inundation; assume a moderate-to-high likelihood that some areas will experience flood depths beyond today’s tolerances after 2050. Probability of marginal benefits from adaptation depends on local hydrodynamics and landform.\n  - Storm surge/frequency: Increasing; probability of more frequent, higher surge events during extreme rainfall/frost events is high. \n- Exposure and equity\n  - CBD and several low-income neighborhoods are in the current 100-year floodplain; risk is persistent and disproportionally borne by low-income households and small businesses. Probability that a spike in flood risk disproportionately affects vulnerable groups is high.\n- Financial and political\n  - Capital available: ~$600M over 10 years; annual budget ~$2B; asset at risk ~$20B. Probability of additional federal/state funding is moderate but uncertain; debt capacity and political will will shape timing.\n- Technology and maintenance\n  - Green infrastructure performance is plausible but maintenance-heavy; success depends on local governance, staffing, and resident engagement. Probability of underinvestment in maintenance is a risk.\n- Social tolerance and displacement\n  - Community acceptance of managed retreat varies; probability of resistance in some neighborhoods is nontrivial. Targeted buyouts and replacement housing programs will require careful design and transparency.\n\n3) 10-year and 30-year timeline, rough costs, and funding strategies\n- 10-year plan (0–10 years)\n  - Core actions:\n    - Implement a citywide resilience program with a governance unit (resilience/climate office).\n    - Deploy a broad green infrastructu ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# Below is a structured policy advisory tailored to a mid-sized coastal city facing significant flood and sea-level-rise risk. It blends engineering, nature-based solutions, and orderly planning for managed retreat, with equity at the center.
#
# 1) Clear recommendation and principal rationale
# - Recommendation: Adopt a hybrid strategy (Option D) that combines:
#   - Green/soft infrastructure and elevation-focused protections for the most critical assets and neighborhoods (Option C components applied citywide where feasible),
#   - Selective small-scale flood barriers and barriers around key chokepoints (light gray/gray infrastructure),
#   - A disciplined, time-phased plan for managed retreat and buyouts in the most vulnerable neighborhoods, with preserves for growth on higher ground and replacement housing in safe areas (Option B components applied selectively and in staged fashion),
#   - A potential larger-scale waterfront protection only if risk, demand, and funding justify it later (scenario-responsive siting, not a fixed upfront seawall).
# - Why this combination:
#   - Sea-level rise is ongoing and uncertain (0.6 m by 2050, ~1.2 m by 2100 with tail risk), while storm surge is intensifying. A single “wall” solution is risky, unaffordable at scale, and creates equity and maintenance challenges; wholesale retreat is politically difficult and costly if pursued too aggressively too early. A hybrid approach spreads risk, preserves affordable options for low-income residents, protects critical assets, and builds adaptive capacity as new data arrives.
#   - Green infrastructure provides co-benefits (cooling, urban heat mitigation, water quality, recreation) and is generally more adaptable to changing conditions. Elevation and selective barriers protect critical nodes (schools, hospitals, transit nodes, emergency services). Phased managed retreat reduces long-term exposure and public liability while enabling new affordable housing and economic opportunities in safer areas. A flexible plan survives many futures and is more defensible to funders and the public.
#
# 2) Key assumptions and uncertainties (qualitative probabilities)
# - Climate and hazards
#   - SLR: Median projections are ~0.6 m (2050) and ~1.2 m (2100); upper tail could reach ~1.5 m by 2100. Probability of higher-than-median outcomes increases the risk of coastal inundation; assume a moderate-to-high likelihood that some areas will experience flood depths beyond today’s tolerances after 2050. Probability of marginal benefits from adaptation depends on local hydrodynamics and landform.
#   - Storm surge/frequency: Increasing; probability of more frequent, higher surge events during extreme rainfall/frost events is high.
# - Exposure and equity
#   - CBD and several low-income neighborhoods are in the current 100-year floodplain; risk is persistent and disproportionally borne by low-income households and small businesses. Probability that a spike in flood risk disproportionately affects vulnerable groups is high.
# - Financial and political
#   - Capital available: ~$600M over 10 years; annual budget ~$2B; asset at risk ~$20B. Probability of additional federal/state funding is moderate but uncertain; debt capacity and political will will shape timing.
# - Technology and maintenance
#   - Green infrastructure performance is plausible but maintenance-heavy; success depends on local governance, staffing, and resident engagement. Probability of underinvestment in maintenance is a risk.
# - Social tolerance and displacement
#   - Community acceptance of managed retreat varies; probability of resistance in some neighborhoods is nontrivial. Targeted buyouts and replacement housing programs will require careful design and transparency.
#
# 3) 10-year and 30-year timeline, rough costs, and funding strategies
# - 10-year plan (0–10 years)
#   - Core actions:
#     - Implement a citywide resilience program with a governance unit (resilience/climate office).
#     - Deploy a broad green infrastructure program (green streets, bioswales, permeable pavements, rain gardens) in selected high-priority neighborhoods; elevate or flood-proof critical facilities (schools, clinics, emergency operations centers, water/waste facilities).
#     - Install selective small-scale barriers and low-cost gray protections around critical bottlenecks (e.g., grade-separated crossings, floodgates at key drainage inlets, temporary/permanent barrier improvements where cost-effective).
#     - Begin an equitable retreat-readiness pathway: establish a buyout fund, target a limited number of households for voluntary relocation in the most exposed zones, and begin land-use planning for safe, affordable replacement housing on higher ground.
#     - Initiate a robust flood-risk and asset map refresh with LIDAR, hydrodynamic modeling, and community risk perception surveys.
#   - Rough cost range (10-year window):
#     - Green/blue infrastructure, elevation of assets, small barriers: $450–$750M.
#     - Buyout funding and relocation readiness for a subset of the most vulnerable parcels: $100–$250M (initial tranche; scalable to year 10 depending on risk).
#     - Planning, design, land acquisition, project management, resilience office operations: $50–$100M.
#     - Total 10-year capital needs (rough): $600M. This aligns with the city’s 10-year capital envelope and leverages some federal/state funding and bonds.
#   - Funding strategy:
#     - A mix of municipal bonds (general obligation or revenue-backed), state/federal resilience grants, community development finance locally (CDFI-backed), and public-private partnerships where applicable.
#     - Establish a resilience fund/line of credit as a contingency for overruns.
#     - Seek federal/state programs focused on disaster resilience, climate adaptation, and buyouts; pursue insurance-related resilience grant programs where available.
# - 30-year horizon (10–30 years)
#   - Actions:
#     - Scale green infrastructure and flood-proofing citywide, prioritizing neighborhoods with remaining exposure.
#     - Expand managed retreat in a phased, consent-based manner in the most exposed areas; create replacement housing and economic opportunities in safer zones; implement land-use changes to prevent new construction in high-risk areas.
#     - Reassess the value and role of a waterfront protection feature after monitoring, data, and risk appetite: consider a targeted seawall or barrier around critical corridors if conditions justify it and funding becomes available, but only with a carefully justified cost-benefit and equity safeguards.
#   - Rough cost range (30-year program beyond year 10):
#     - Expanded green infrastructure and elevation: $1–2.5B (over 20 years), depending on scale and communities engaged.
#     - Managed retreat and housing replacement: $1–3B (depending on pace, land costs, and housing stock policy; could be higher if large-scale buyouts occur).
#     - Seawall/barrier (if triggered later): $1–3B depending on length, height, and protection level required.
#     - Total 30-year program (incremental, if fully pursued as described): potentially $2–5B+ beyond year 10, highly contingent on risk trajectory and funding success.
#   - Funding strategy:
#     - Expanded state/federal grants tied to resilience, hazard mitigation, and climate adaptation.
#     - Long-term municipal bonds or value capture financing for area-specific protections.
#     - New housing trust funds and incentives to stimulate development on higher ground; state-backed affordable housing programs to finance replacement housing in retreat zones.
#     - Public-private partnerships and performance-based contracts for maintenance of green infrastructure.
# - Overall perspective
#   - The city should begin now with 0–10-year investments that demonstrate measurable risk reduction, track costs, and build trust with residents. The 10–20 year window should show performance data to justify ongoing, scaled retreat and any potential waterfront protection decisions. Keep the option of a waterfront barrier as a late-stage, data-driven decision, not as a default.
#
# 4) Distributional impacts on low-income and vulnerable residents and equity measures
# - Impacts to watch
#   - Without safeguards, retreat could cluster in ways that displace low-income households and disrupt existing communities, jobs, and access to services.
#   - Green infrastructure investments can benefit low-income neighborhoods through flood reduction and health co-benefits but require ongoing maintenance commitments to avoid neglect.
# - Mitigation measures
#   - Equity-centered design: prioritize protection of high-risk, low-income neighborhoods with early-stage green infrastructure and non-displacing protections; ensure essential services remain accessible.
#   - Transparent, voluntary buyouts: use clear criteria, fair appraisals, and predictable timelines; allow local hire and contractor preferences for residents.
#   - Replacement housing and mobility: create affordable housing options on higher ground with access to jobs, transit, and essential services; guarantee a right-to-return for displaced residents where feasible.
#   - Economic inclusion: require local hiring for resilience projects, support small and minority-owned businesses in flood-prone areas, and provide microgrants for home elevation and flood-proofing.
#   - Financial protections: offer property tax relief or subsidies for residents who participate in buyouts; provide temporary rental assistance and subsidies for displaced residents; maintain mental-health and community services during transition.
#   - Community engagement: continuous, accessible (multi-language) community engagement; involve residents in planning decisions to ensure culturally appropriate and acceptable solutions.
# - Concrete measures
#   - Set aside a minimum % of capital for affordable housing in retreat zones and for housing replacement on higher ground.
#   - Protect tenants with strong affordability covenants in replacement housing; ensure housing density and design accommodate families of varying sizes.
#   - Ensure critical services (water, health, emergency response) remain functional and accessible throughout retreat and adaptation phases.
#   - Create local job pipelines for resilience projects (construction, maintenance, planning, monitoring) to build community capacity and economic resilience.
#
# 5) Monitoring indicators and decision triggers (thresholds)
# - Hazard and exposure indicators
#   - Sea-level rise metrics: track observed vs. modeled SLR by neighborhood; trigger re-evaluation if observed rates exceed projections by >20% over a 5-year period.
#   - Flood depth/extent: monitor nuisance flooding frequency and depth in the CBD and low-income neighborhoods; trigger adaptive design modifications if flash or high-tide flooding exceeds X inches/depth for Y events per year over 3 consecutive years.
#   - Storm surge events: track frequency/intensity; trigger enhanced protective measures if surge events exceed forecasted baselines in consecutive seasons.
# - Infrastructure performance indicators
#   - Green infrastructure performance: measure runoff capture, water quality benefits, maintenance cost per area; trigger adjustments if capture is below target during a full-year monitoring period.
#   - Elevation and barrier performance: monitor structure integrity, closure times, maintenance needs; trigger upgrades if performance degrades or if there is repeated failure during events.
# - Social and equity indicators
#   - Displacement/relocation metrics: number of households in buyouts, time-to-move, access to replacement housing; trigger policy review if displacement exceeds planned thresholds or if community concerns rise sharply.
#   - Housing and economic outcomes: track affordable housing units created, job placement for residents in resilience projects, and changes in property values near protections; trigger rebalancing of investments if negative trends persist.
# - Financial indicators
#   - Cost overruns, funding gaps, and debt service: track against budget; trigger reallocation or additional funding strategies if overruns approach a predefined threshold (e.g., 20% over budget or 10% schedule slippage).
# - Data sources and governance
#   - Establish a resilient-data dashboard with quarterly reporting to the mayor and council; include community input mechanisms to ensure transparency.
#
# Decision triggers
# - If SLR/storm data indicate significantly higher risk than current plan (e.g., >20% higher water levels or higher frequency of severe surge within 5–10 years), accelerate targeted protections and accelerate retreat planning in vulnerable zones.
# - If funding prospects improve (state/federal grants, favorable treasury conditions) and risk-adjusted ROI remains favorable, scale up hybrid protections or accelerate buyouts where equity considerations are strongest.
# - If equity concerns rise due to displacement or loss of housing affordability, pause high-disruption moves and reallocate funds toward protection and affordable replacement housing closer to existing communities.
#
# 6) Top three risks or failure modes and mitigations
# - Risk 1: Underfunding or cost overruns; mitigation: rigorous, staged financing plan; reserve funds; flex in scope; pursue multiple funding streams (bonds, grants, public-private partnerships) and establish a contingency fund. Maintain transparent reporting and public accountability to preserve support.
# - Risk 2: Equity failures and community resistance to retreat; mitigation: invest early in inclusive planning; ensure consent-based buyouts with robust protections; provide strong replacement housing and job opportunities; implement tenant protections and rent subsidies; ensure ongoing community benefits from resilience investments.
# - Risk 3: Maintenance and performance gaps in green infrastructure; mitigation: build local capacity for operations and maintenance; adopt performance-based contracts; require maintenance funds and clear accountability; implement adaptive management to address climate variability.
# - Additional risk: Data uncertainty and political risk; mitigation: decision rules anchored in adaptive management, with defined triggers and rollback options; maintain flexibility to reallocate funds in response to new data or events.
#
# 7) Three prioritized short-term actions (0–5 years) and one pilot project to reduce critical uncertainty
# - Short-term actions (0–5 years)
#   - Action 1: Establish a dedicated resilience governance unit with a clear funding strategy, risk modeling capability, equity-focused design standards, and a detailed data dashboard for ongoing decision-making.
#   - Action 2: Implement 2–3 targeted green infrastructure pilots in high-risk, high-need neighborhoods (e.g., bioswales, permeable pavements, rain gardens, elevated walkways) and upgrade 2–3 critical facilities (schools, clinics, emergency operations) with flood-proofing and backup power. Begin resident outreach on retreat options, and set up a buyout assistance framework.
#   - Action 3: Create a phased, voluntary retreat-readiness plan for the most exposed neighborhoods, including a pilot buyout of a limited number of households, with replacement housing planning, and a local workforce development program to ensure residents can participate in resilience work.
# - Pilot project designed to reduce critical uncertainty
#   - Pilot Project: A 1–2 mile waterfront resilience corridor combining green-blue infrastructure with a modular, low-cost barrier at a critical inlet. This project would be designed as a controlled, data-rich test of:
#     - How green infrastructure reduces flood depth and frequency in a real neighborhood setting,
#     - The incremental cost and performance of low-cost barriers integrated with green systems,
#     - Social acceptability, maintenance needs, and job-creation potential for residents.
#   - Outcomes to measure in the pilot: flood reduction performance, maintenance costs, resident satisfaction, economic impact, and lessons for scaling the approach citywide.
#
# 8) Confidence statement and events that could change the recommendation
# - Confidence level: Medium to High
#   - Rationale: A hybrid approach provides a balanced, adaptable path that mitigates risk from multiple angles, aligns with equity goals, and leverages a broad range of funding opportunities. It also avoids the political and fiscal risks of a single heavy infrastructure push (like a city-wide seawall) or an overly rapid retreat entirely funded by the city.
# - What new evidence or events could most likely change the recommendation:
#   - Funding landscape: If federal/state resilience funding expands significantly or if a major public-private financing mechanism becomes available, a more protective waterfront barrier (or expanded full seawall) could become viable and attractive earlier than planned, potentially shifting more emphasis toward gray infrastructure.
#   - Risk realization: If observed watershed and coastal data indicate a more severe or earlier-than-expected flood regime (e.g., rapid SLR acceleration, higher storm surge frequency), the city might accelerate retreat in certain zones or scale up protection in critical corridors sooner.
#   - Equity and social response: If community engagement reveals widespread opposition to retreat or if displacement risks become politically unsustainable, the plan would need to adjust toward protection and incremental, voluntary retreat with stronger support measures.
#   - Infrastructure performance data: If pilots clearly demonstrate cost-effective flood reduction and scalable maintenance, the city may accelerate green infrastructure deployment and reduce the need for expensive hard barriers.
#
# Notes for executive decision-makers
# - This plan intentionally prioritizes a flexible, equitable, and data-driven approach. It preserves options for scalable protection, prioritizes protecting essential assets, and uses retreat strategically where the risk is highest and the costs are manageable.
# - The equity lens is non-negotiable: protections, housing, and economic opportunities must be accessible to low-income residents who are most exposed.
# - Governance, public engagement, and robust data are essential to keep this plan adaptive and credible to residents, funders, and stakeholders.
#
# If you’d like, I can translate this into a more formal policy memo with a one-page executive summary, a 2–3 page implementation plan for the next 12–18 months, and a high-level budget and financing outline tailored to your city’s specific budgetary and political context.
# Competitor: llama3.2
#
# **Recommendation:** A hybrid strategy incorporating aspects of options B, C, and D.
#
# **Principal Rationale:**
#
# 1. **Mitigate flood risk while considering long-term resilience**: The hybrid approach will combine the benefits of phased managed retreat with targeted green infrastructure and elevation/flood-proofing measures to protect vulnerable areas. This multi-faceted strategy acknowledges the ongoing threat of sea-level rise and storm surge enhancements while allowing for adaptive management in response to changing conditions.
# 2. **Optimize resource allocation**: By combining elements from each option, the hybrid approach utilizes a mix of short-term (A), mid-term (C), and long-term (B) solutions, ensuring that capital is allocated efficiently across different scales and timeframes.
# 3. **Address distributional impacts and equity concerns**: The hybrid strategy prioritizes inclusive adaptation, incorporating measures designed to support vulnerable populations and ensure equitable outcomes.
#
# **Key Assumptions and Uncertainties:**
#
# 1. Sea-level rise (SLR) projections are reliable (~70% certainty), but some variability exists (20%.
# 2. Projected storm surge intensity and frequency are plausible within current projections (~50% confidence).
# 3. Adaptive management effectiveness in response to changing conditions is uncertain (~30% probability).

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Below is a structured policy advisory tailored to a mid-sized coastal city facing significant flood and sea-level-rise risk. It blends engineering, nature-based solutions, and orderly planning for managed retreat, with equity at the center.
#
# 1) Clear recommendation and principal rationale
# - Recommendation: Adopt a hybrid strategy (Option D) that combines:
#   - Green/soft infrastructure and elevation-focused protections for the most critical assets and neighborhoods (Option C components applied citywide where feasible),
#   - Selective small-scale flood barriers and barriers around key chokepoints (light gray/gray infrastructure),
#   - A disciplined, time-phased plan for managed retreat and buyouts in the most vulnerable neighborhoods, with preserves for growth on higher ground and replacement housing in safe areas (Option B components applied selectively and in staged fashion),
#   - A potential larger-scale waterfront protection only if risk, demand, and funding justify it later (scenario-responsive siting, not a fixed upfront seawall).
# - Why this combination:
#   - Sea-level rise is ongoing and uncertain (0.6 m by 2050, ~1.2 m by 2100 with tail risk), while storm surge is intensifying. A single “wall” solution is risky, unaffordable at scale, and creates equity and maintenance challenges; wholesale retreat is politically difficult and costly if pursued too aggressively too early. A hybrid approach spreads risk, preserves affordable options for low-income residents, protects critical assets, and builds adaptive capacity as new data arrives.
#   - Green infrastructure provides co-benefits (cooling, urban heat mitigation, water quality, recreation) and is generally more adaptable to changing conditions. Elevation and selective barriers protect critical nodes (schools, hospitals, transit nodes, emergency services). Phased managed retreat reduces long-term exposure and public liability while enabling new affordable housing and economic opportunities in safer areas. A flexible plan survives many futures and is more defensible to funders and the public.
#
# 2) Key assumptions and uncertainties (qualitative probabilities)
# - Climate and hazards
#   - SLR: Median projections are ~0.6 m (2050) and ~1.2 m (2100); upper tail could reach ~1.5 m by 2100. Probability of higher-than-median outcomes increases the risk of coastal inundation; assume a moderate-to-high likelihood that some areas will experience flood depths beyond today’s tolerances after 2050. Probability of marginal benefits from adaptation depends on local hydrodynamics and landform.
#   - Storm surge/frequency: Increasing; probability of more frequent, higher surge events during extreme rainfall/frost events is high.
# - Exposure and equity
#   - CBD and several low-income neighborhoods are in the current 100-year floodplain; risk is persistent and disproportionally borne by low-income households and small businesses. Probability that a spike in flood risk disproportionately affects vulnerable groups is high.
# - Financial and political
#   - Capital available: ~$600M over 10 years; annual budget ~$2B; asset at risk ~$20B. Probability of additional federal/state funding is moderate but uncertain; debt capacity and political will will shape timing.
# - Technology and maintenance
#   - Green infrastructure performance is plausible but maintenance-heavy; success depends on local governance, staffing, and resident engagement. Probability of underinvestment in maintenance is a risk.
# - Social tolerance and displacement
#   - Community acceptance of managed retreat varies; probability of resistance in some neighborhoods is nontrivial. Targeted buyouts and replacement housing programs will require careful design and transparency.
#
# 3) 10-year and 30-year timeline, rough costs, and funding strategies
# - 10-year plan (0–10 years)
#   - Core actions:
#     - Implement a citywide resilience program with a governance unit (resilience/climate office).
#     - Deploy a broad green infrastructure program (green streets, bioswales, permeable pavements, rain gardens) in selected high-priority neighborhoods; elevate or flood-proof critical facilities (schools, clinics, emergency operations centers, water/waste facilities).
#     - Install selective small-scale barriers and low-cost gray protections around critical bottlenecks (e.g., grade-separated crossings, floodgates at key drainage inlets, temporary/permanent barrier improvements where cost-effective).
#     - Begin an equitable retreat-readiness pathway: establish a buyout fund, target a limited number of households for voluntary relocation in the most exposed zones, and begin land-use planning for safe, affordable replacement housing on higher ground.
#     - Initiate a robust flood-risk and asset map refresh with LIDAR, hydrodynamic modeling, and community risk perception surveys.
#   - Rough cost range (10-year window):
#     - Green/blue infrastructure, elevation of assets, small barriers: $450–$750M.
#     - Buyout funding and relocation readiness for a subset of the most vulnerable parcels: $100–$250M (initial tranche; scalable to year 10 depending on risk).
#     - Planning, design, land acquisition, project management, resilience office operations: $50–$100M.
#     - Total 10-year capital needs (rough): $600M. This aligns with the city’s 10-year capital envelope and leverages some federal/state funding and bonds.
#   - Funding strategy:
#     - A mix of municipal bonds (general obligation or revenue-backed), state/federal resilience grants, community development finance locally (CDFI-backed), and public-private partnerships where applicable.
#     - Establish a resilience fund/line of credit as a contingency for overruns.
#     - Seek federal/state programs focused on disaster resilience, climate adaptation, and buyouts; pursue insurance-related resilience grant programs where available.
# - 30-year horizon (10–30 years)
#   - Actions:
#     - Scale green infrastructure and flood-proofing citywide, prioritizing neighborhoods with remaining exposure.
#     - Expand managed retreat in a phased, consent-based manner in the most exposed areas; create replacement housing and economic opportunities in safer zones; implement land-use changes to prevent new construction in high-risk areas.
#     - Reassess the value and role of a waterfront protection feature after monitoring, data, and risk appetite: consider a targeted seawall or barrier around critical corridors if conditions justify it and funding becomes available, but only with a carefully justified cost-benefit and equity safeguards.
#   - Rough cost range (30-year program beyond year 10):
#     - Expanded green infrastructure and elevation: $1–2.5B (over 20 years), depending on scale and communities engaged.
#     - Managed retreat and housing replacement: $1–3B (depending on pace, land costs, and housing stock policy; could be higher if large-scale buyouts occur).
#     - Seawall/barrier (if triggered later): $1–3B depending on length, height, and protection level required.
#     - Total 30-year program (incremental, if fully pursued as described): potentially $2–5B+ beyond year 10, highly contingent on risk trajectory and funding success.
#   - Funding strategy:
#     - Expanded state/federal grants tied to resilience, hazard mitigation, and climate adaptation.
#     - Long-term municipal bonds or value capture financing for area-specific protections.
#     - New housing trust funds and incentives to stimulate development on higher ground; state-backed affordable housing programs to finance replacement housing in retreat zones.
#     - Public-private partnerships and performance-based contracts for maintenance of green infrastructure.
# - Overall perspective
#   - The city should begin now with 0–10-year investments that demonstrate measurable risk reduction, track costs, and build trust with residents. The 10–20 year window should show performance data to justify ongoing, scaled retreat and any potential waterfront protection decisions. Keep the option of a waterfront barrier as a late-stage, data-driven decision, not as a default.
#
# 4) Distributional impacts on low-income and vulnerable residents and equity measures
# - Impacts to watch
#   - Without safeguards, retreat could cluster in ways that displace low-income households and disrupt existing communities, jobs, and access to services.
#   - Green infrastructure investments can benefit low-income neighborhoods through flood reduction and health co-benefits but require ongoing maintenance commitments to avoid neglect.
# - Mitigation measures
#   - Equity-centered design: prioritize protection of high-risk, low-income neighborhoods with early-stage green infrastructure and non-displacing protections; ensure essential services remain accessible.
#   - Transparent, voluntary buyouts: use clear criteria, fair appraisals, and predictable timelines; allow local hire and contractor preferences for residents.
#   - Replacement housing and mobility: create affordable housing options on higher ground with access to jobs, transit, and essential services; guarantee a right-to-return for displaced residents where feasible.
#   - Economic inclusion: require local hiring for resilience projects, support small and minority-owned businesses in flood-prone areas, and provide microgrants for home elevation and flood-proofing.
#   - Financial protections: offer property tax relief or subsidies for residents who participate in buyouts; provide temporary rental assistance and subsidies for displaced residents; maintain mental-health and community services during transition.
#   - Community engagement: continuous, accessible (multi-language) community engagement; involve residents in planning decisions to ensure culturally appropriate and acceptable solutions.
# - Concrete measures
#   - Set aside a minimum % of capital for affordable housing in retreat zones and for housing replacement on higher ground.
#   - Protect tenants with strong affordability covenants in replacement housing; ensure housing density and design accommodate families of varying sizes.
#   - Ensure critical services (water, health, emergency response) remain functional and accessible throughout retreat and adaptation phases.
#   - Create local job pipelines for resilience projects (construction, maintenance, planning, monitoring) to build community capacity and economic resilience.
#
# 5) Monitoring indicators and decision triggers (thresholds)
# - Hazard and exposure indicators
#   - Sea-level rise metrics: track observed vs. modeled SLR by neighborhood; trigger re-evaluation if observed rates exceed projections by >20% over a 5-year period.
#   - Flood depth/extent: monitor nuisance flooding frequency and depth in the CBD and low-income neighborhoods; trigger adaptive design modifications if flash or high-tide flooding exceeds X inches/depth for Y events per year over 3 consecutive years.
#   - Storm surge events: track frequency/intensity; trigger enhanced protective measures if surge events exceed forecasted baselines in consecutive seasons.
# - Infrastructure performance indicators
#   - Green infrastructure performance: measure runoff capture, water quality benefits, maintenance cost per area; trigger adjustments if capture is below target during a full-year monitoring period.
#   - Elevation and barrier performance: monitor structure integrity, closure times, maintenance needs; trigger upgrades if performance degrades or if there is repeated failure during events.
# - Social and equity indicators
#   - Displacement/relocation metrics: number of households in buyouts, time-to-move, access to replacement housing; trigger policy review if displacement exceeds planned thresholds or if community concerns rise sharply.
#   - Housing and economic outcomes: track affordable housing units created, job placement for residents in resilience projects, and changes in property values near protections; trigger rebalancing of investments if negative trends persist.
# - Financial indicators
#   - Cost overruns, funding gaps, and debt service: track against budget; trigger reallocation or additional funding strategies if overruns approach a predefined threshold (e.g., 20% over budget or 10% schedule slippage).
# - Data sources and governance
#   - Establish a resilient-data dashboard with quarterly reporting to the mayor and council; include community input mechanisms to ensure transparency.
#
# Decision triggers
# - If SLR/storm data indicate significantly higher risk than current plan (e.g., >20% higher water levels or higher frequency of severe surge within 5–10 years), accelerate targeted protections and accelerate retreat planning in vulnerable zones.
# - If funding prospects improve (state/federal grants, favorable treasury conditions) and risk-adjusted ROI remains favorable, scale up hybrid protections or accelerate buyouts where equity considerations are strongest.
# - If equity concerns rise due to displacement or loss of housing affordability, pause high-disruption moves and reallocate funds toward protection and affordable replacement housing closer to existing communities.
#
# 6) Top three risks or failure modes and mitigations
# - Risk 1: Underfunding or cost overruns; mitigation: rigorous, staged financing plan; reserve funds; flex in scope; pursue multiple funding streams (bonds, grants, public-private partnerships) and establish a contingency fund. Maintain transparent reporting and public accountability to preserve support.
# - Risk 2: Equity failures and community resistance to retreat; mitigation: invest early in inclusive planning; ensure consent-based buyouts with robust protections; provide strong replacement housing and job opportunities; implement tenant protections and rent subsidies; ensure ongoing community benefits from resilience investments.
# - Risk 3: Maintenance and performance gaps in green infrastructure; mitigation: build local capacity for operations and maintenance; adopt performance-based contracts; require maintenance funds and clear accountability; implement adaptive management to address climate variability.
# - Additional risk: Data uncertainty and political risk; mitigation: decision rules anchored in adaptive management, with defined triggers and rollback options; maintain flexibility to reallocate funds in response to new data or events.
#
# 7) Three prioritized short-term actions (0–5 years) and one pilot project to reduce critical uncertainty
# - Short-term actions (0–5 years)
#   - Action 1: Establish a dedicated resilience governance unit with a clear funding strategy, risk modeling capability, equity-focused design standards, and a detailed data dashboard for ongoing decision-making.
#   - Action 2: Implement 2–3 targeted green infrastructure pilots in high-risk, high-need neighborhoods (e.g., bioswales, permeable pavements, rain gardens, elevated walkways) and upgrade 2–3 critical facilities (schools, clinics, emergency operations) with flood-proofing and backup power. Begin resident outreach on retreat options, and set up a buyout assistance framework.
#   - Action 3: Create a phased, voluntary retreat-readiness plan for the most exposed neighborhoods, including a pilot buyout of a limited number of households, with replacement housing planning, and a local workforce development program to ensure residents can participate in resilience work.
# - Pilot project designed to reduce critical uncertainty
#   - Pilot Project: A 1–2 mile waterfront resilience corridor combining green-blue infrastructure with a modular, low-cost barrier at a critical inlet. This project would be designed as a controlled, data-rich test of:
#     - How green infrastructure reduces flood depth and frequency in a real neighborhood setting,
#     - The incremental cost and performance of low-cost barriers integrated with green systems,
#     - Social acceptability, maintenance needs, and job-creation potential for residents.
#   - Outcomes to measure in the pilot: flood reduction performance, maintenance costs, resident satisfaction, economic impact, and lessons for scaling the approach citywide.
#
# 8) Confidence statement and events that could change the recommendation
# - Confidence level: Medium to High
#   - Rationale: A hybrid approach provides a balanced, adaptable path that mitigates risk from multiple angles, aligns with equity goals, and leverages a broad range of funding opportunities. It also avoids the political and fiscal risks of a single heavy infrastructure push (like a city-wide seawall) or an overly rapid retreat entirely funded by the city.
# - What new evidence or events could most likely change the recommendation:
#   - Funding landscape: If federal/state resilience funding expands significantly or if a major public-private financing mechanism becomes available, a more protective waterfront barrier (or expanded full seawall) could become viable and attractive earlier than planned, potentially shifting more emphasis toward gray infrastructure.
#   - Risk realization: If observed watershed and coastal data indicate a more severe or earlier-than-expected flood regime (e.g., rapid SLR acceleration, higher storm surge frequency), the city might accelerate retreat in certain zones or scale up protection in critical corridors sooner.
#   - Equity and social response: If community engagement reveals widespread opposition to retreat or if displacement risks become politically unsustainable, the plan would need to adjust toward protection and incremental, voluntary retreat with stronger support measures.
#   - Infrastructure performance data: If pilots clearly demonstrate cost-effective flood reduction and scalable maintenance, the city may accelerate green infrastructure deployment and reduce the need for expensive hard barriers.
#
# Notes for executive decision-makers
# - This plan intentionally prioritizes a flexible, equitable, and data-driven approach. It preserves options for scalable protection, prioritizes protecting essential assets, and uses retreat strategically where the risk is highest and the costs are manageable.
# - The equity lens is non-negotiable: protections, housing, and economic opportunities must be accessible to low-income residents who are most exposed.
# - Governance, public engagement, and robust data are essential to keep this plan adaptive and credible to residents, funders, and stakeholders.
#
# If you’d like, I can translate this into a more formal policy memo with a one-page executive summary, a 2–3 page implementation plan for the next 12–18 months, and a high-level budget and financing outline tailored to your city’s specific budgetary and political context.
#
# # Response from competitor 2
#
# **Recommendation:** A hybrid strategy incorporating aspects of options B, C, and D.
#
# **Principal Rationale:**
#
# 1. **Mitigate flood risk while considering long-term resilience**: The hybrid approach will combine the benefits of phased managed retreat with targeted green infrastructure and elevation/flood-proofing measures to protect vulnerable areas. This multi-faceted strategy acknowledges the ongoing threat of sea-level rise and storm surge enhancements while allowing for adaptive management in response to changing conditions.
# 2. **Optimize resource allocation**: By combining elements from each option, the hybrid approach utilizes a mix of short-term (A), mid-term (C), and long-term (B) solutions, ensuring that capital is allocated efficiently across different scales and timeframes.
# 3. **Address distributional impacts and equity concerns**: The hybrid strategy prioritizes inclusive adaptation, incorporating measures designed to support vulnerable populations and ensure equitable outcomes.
#
# **Key Assumptions and Uncertainties:**
#
# 1. Sea-level rise (SLR) projections are reliable (~70% certainty), but some variability exists (20%.
# 2. Projected storm surge intensity and frequency are plausible within current projections (~50% confidence).
# 3. Adaptive management effectiveness in response to changing conditions is uncertain (~30% probability).

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 2 competitors.
# Each model has been given this question:
#
# You are advising the mayor of a mid-sized coastal city (population 500,000) whose central business district and several low-income neighborhoods lie in the current 100-year floodplain. The city has $600M in capital available for the next decade, municipal assets at risk valued at ~$20B, and an annual city budget of $2B. Sea-level-rise projections for the city are a median of ~0.6 m by 2050 and ~1.2 m by 2100, with a plausible upper tail to ~1.5 m by 2100; storm surge intensity and frequency are increasing. The mayor must choose among: (A) building a large seawall to protect the CBD and waterfront, (B) planning and funding phased managed retreat from the most vulnerable areas over ~30 years, (C) implementing distributed “green infrastructure” and elevation/flood-proofing with selective small barriers, or (D) a hybrid strategy. Which option or combination do you recommend, and why? In your answer, provide (1) a clear recommendation and the principal rationale; (2) the key assumptions you are making and their uncertainties (give qualitative probabilities where useful); (3) an estimated 10-year and 30-year timeline with rough cost ranges and plausible funding strategies; (4) an analysis of distributional impacts on low-income and vulnerable residents and concrete mitigation measures to ensure equity; (5) specific monitoring indicators and decision “triggers” (with thresholds) that would prompt changing course; (6) the top three risks or failure modes for your recommendation and mitigations for each; (7) three prioritized short-term actions (0–5 years) and one pilot project designed to reduce critical uncertainty; and (8) a concise statement of your confidence in the recommendation (low/medium/high) and which new evidence or events would most likely change it.
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Below is a structured policy advisory tailored to a mid-sized coastal city facing significant flood and sea-level-rise risk. It blends engineering, nature-based solutions, and orderly planning for managed retreat, with equity at the center.
#
# 1) Clear recommendation and principal rationale
# - Recommendation: Adopt a hybrid strategy (Option D) that combines:
#   - Green/soft infrastructure and elevation-focused protections for the most critical assets and neighborhoods (Option C components applied citywide where feasible),
#   - Selective small-scale flood barriers and barriers around key chokepoints (light gray/gray infrastructure),
#   - A disciplined, time-phased plan for managed retreat and buyouts in the most vulnerable neighborhoods, with preserves for growth on higher ground and replacement housing in safe areas (Option B components applied selectively and in staged fashion),
#   - A potential larger-scale waterfront protection only if risk, demand, and funding justify it later (scenario-responsive siting, not a fixed upfront seawall).
# - Why this combination:
#   - Sea-level rise is ongoing and uncertain (0.6 m by 2050, ~1.2 m by 2100 with tail risk), while storm surge is intensifying. A single “wall” solution is risky, unaffordable at scale, and creates equity and maintenance challenges; wholesale retreat is politically difficult and costly if pursued too aggressively too early. A hybrid approach spreads risk, preserves affordable options for low-income residents, protects critical assets, and builds adaptive capacity as new data arrives.
#   - Green infrastructure provides co-benefits (cooling, urban heat mitigation, water quality, recreation) and is generally more adaptable to changing conditions. Elevation and selective barriers protect critical nodes (schools, hospitals, transit nodes, emergency services). Phased managed retreat reduces long-term exposure and public liability while enabling new affordable housing and economic opportunities in safer areas. A flexible plan survives many futures and is more defensible to funders and the public.
#
# 2) Key assumptions and uncertainties (qualitative probabilities)
# - Climate and hazards
#   - SLR: Median projections are ~0.6 m (2050) and ~1.2 m (2100); upper tail could reach ~1.5 m by 2100. Probability of higher-than-median outcomes increases the risk of coastal inundation; assume a moderate-to-high likelihood that some areas will experience flood depths beyond today’s tolerances after 2050. Probability of marginal benefits from adaptation depends on local hydrodynamics and landform.
#   - Storm surge/frequency: Increasing; probability of more frequent, higher surge events during extreme rainfall/frost events is high.
# - Exposure and equity
#   - CBD and several low-income neighborhoods are in the current 100-year floodplain; risk is persistent and disproportionally borne by low-income households and small businesses. Probability that a spike in flood risk disproportionately affects vulnerable groups is high.
# - Financial and political
#   - Capital available: ~$600M over 10 years; annual budget ~$2B; asset at risk ~$20B. Probability of additional federal/state funding is moderate but uncertain; debt capacity and political will will shape timing.
# - Technology and maintenance
#   - Green infrastructure performance is plausible but maintenance-heavy; success depends on local governance, staffing, and resident engagement. Probability of underinvestment in maintenance is a risk.
# - Social tolerance and displacement
#   - Community acceptance of managed retreat varies; probability of resistance in some neighborhoods is nontrivial. Targeted buyouts and replacement housing programs will require careful design and transparency.
#
# 3) 10-year and 30-year timeline, rough costs, and funding strategies
# - 10-year plan (0–10 years)
#   - Core actions:
#     - Implement a citywide resilience program with a governance unit (resilience/climate office).
#     - Deploy a broad green infrastructure program (green streets, bioswales, permeable pavements, rain gardens) in selected high-priority neighborhoods; elevate or flood-proof critical facilities (schools, clinics, emergency operations centers, water/waste facilities).
#     - Install selective small-scale barriers and low-cost gray protections around critical bottlenecks (e.g., grade-separated crossings, floodgates at key drainage inlets, temporary/permanent barrier improvements where cost-effective).
#     - Begin an equitable retreat-readiness pathway: establish a buyout fund, target a limited number of households for voluntary relocation in the most exposed zones, and begin land-use planning for safe, affordable replacement housing on higher ground.
#     - Initiate a robust flood-risk and asset map refresh with LIDAR, hydrodynamic modeling, and community risk perception surveys.
#   - Rough cost range (10-year window):
#     - Green/blue infrastructure, elevation of assets, small barriers: $450–$750M.
#     - Buyout funding and relocation readiness for a subset of the most vulnerable parcels: $100–$250M (initial tranche; scalable to year 10 depending on risk).
#     - Planning, design, land acquisition, project management, resilience office operations: $50–$100M.
#     - Total 10-year capital needs (rough): $600M. This aligns with the city’s 10-year capital envelope and leverages some federal/state funding and bonds.
#   - Funding strategy:
#     - A mix of municipal bonds (general obligation or revenue-backed), state/federal resilience grants, community development finance locally (CDFI-backed), and public-private partnerships where applicable.
#     - Establish a resilience fund/line of credit as a contingency for overruns.
#     - Seek federal/state programs focused on disaster resilience, climate adaptation, and buyouts; pursue insurance-related resilience grant programs where available.
# - 30-year horizon (10–30 years)
#   - Actions:
#     - Scale green infrastructure and flood-proofing citywide, prioritizing neighborhoods with remaining exposure.
#     - Expand managed retreat in a phased, consent-based manner in the most exposed areas; create replacement housing and economic opportunities in safer zones; implement land-use changes to prevent new construction in high-risk areas.
#     - Reassess the value and role of a waterfront protection feature after monitoring, data, and risk appetite: consider a targeted seawall or barrier around critical corridors if conditions justify it and funding becomes available, but only with a carefully justified cost-benefit and equity safeguards.
#   - Rough cost range (30-year program beyond year 10):
#     - Expanded green infrastructure and elevation: $1–2.5B (over 20 years), depending on scale and communities engaged.
#     - Managed retreat and housing replacement: $1–3B (depending on pace, land costs, and housing stock policy; could be higher if large-scale buyouts occur).
#     - Seawall/barrier (if triggered later): $1–3B depending on length, height, and protection level required.
#     - Total 30-year program (incremental, if fully pursued as described): potentially $2–5B+ beyond year 10, highly contingent on risk trajectory and funding success.
#   - Funding strategy:
#     - Expanded state/federal grants tied to resilience, hazard mitigation, and climate adaptation.
#     - Long-term municipal bonds or value capture financing for area-specific protections.
#     - New housing trust funds and incentives to stimulate development on higher ground; state-backed affordable housing programs to finance replacement housing in retreat zones.
#     - Public-private partnerships and performance-based contracts for maintenance of green infrastructure.
# - Overall perspective
#   - The city should begin now with 0–10-year investments that demonstrate measurable risk reduction, track costs, and build trust with residents. The 10–20 year window should show performance data to justify ongoing, scaled retreat and any potential waterfront protection decisions. Keep the option of a waterfront barrier as a late-stage, data-driven decision, not as a default.
#
# 4) Distributional impacts on low-income and vulnerable residents and equity measures
# - Impacts to watch
#   - Without safeguards, retreat could cluster in ways that displace low-income households and disrupt existing communities, jobs, and access to services.
#   - Green infrastructure investments can benefit low-income neighborhoods through flood reduction and health co-benefits but require ongoing maintenance commitments to avoid neglect.
# - Mitigation measures
#   - Equity-centered design: prioritize protection of high-risk, low-income neighborhoods with early-stage green infrastructure and non-displacing protections; ensure essential services remain accessible.
#   - Transparent, voluntary buyouts: use clear criteria, fair appraisals, and predictable timelines; allow local hire and contractor preferences for residents.
#   - Replacement housing and mobility: create affordable housing options on higher ground with access to jobs, transit, and essential services; guarantee a right-to-return for displaced residents where feasible.
#   - Economic inclusion: require local hiring for resilience projects, support small and minority-owned businesses in flood-prone areas, and provide microgrants for home elevation and flood-proofing.
#   - Financial protections: offer property tax relief or subsidies for residents who participate in buyouts; provide temporary rental assistance and subsidies for displaced residents; maintain mental-health and community services during transition.
#   - Community engagement: continuous, accessible (multi-language) community engagement; involve residents in planning decisions to ensure culturally appropriate and acceptable solutions.
# - Concrete measures
#   - Set aside a minimum % of capital for affordable housing in retreat zones and for housing replacement on higher ground.
#   - Protect tenants with strong affordability covenants in replacement housing; ensure housing density and design accommodate families of varying sizes.
#   - Ensure critical services (water, health, emergency response) remain functional and accessible throughout retreat and adaptation phases.
#   - Create local job pipelines for resilience projects (construction, maintenance, planning, monitoring) to build community capacity and economic resilience.
#
# 5) Monitoring indicators and decision triggers (thresholds)
# - Hazard and exposure indicators
#   - Sea-level rise metrics: track observed vs. modeled SLR by neighborhood; trigger re-evaluation if observed rates exceed projections by >20% over a 5-year period.
#   - Flood depth/extent: monitor nuisance flooding frequency and depth in the CBD and low-income neighborhoods; trigger adaptive design modifications if flash or high-tide flooding exceeds X inches/depth for Y events per year over 3 consecutive years.
#   - Storm surge events: track frequency/intensity; trigger enhanced protective measures if surge events exceed forecasted baselines in consecutive seasons.
# - Infrastructure performance indicators
#   - Green infrastructure performance: measure runoff capture, water quality benefits, maintenance cost per area; trigger adjustments if capture is below target during a full-year monitoring period.
#   - Elevation and barrier performance: monitor structure integrity, closure times, maintenance needs; trigger upgrades if performance degrades or if there is repeated failure during events.
# - Social and equity indicators
#   - Displacement/relocation metrics: number of households in buyouts, time-to-move, access to replacement housing; trigger policy review if displacement exceeds planned thresholds or if community concerns rise sharply.
#   - Housing and economic outcomes: track affordable housing units created, job placement for residents in resilience projects, and changes in property values near protections; trigger rebalancing of investments if negative trends persist.
# - Financial indicators
#   - Cost overruns, funding gaps, and debt service: track against budget; trigger reallocation or additional funding strategies if overruns approach a predefined threshold (e.g., 20% over budget or 10% schedule slippage).
# - Data sources and governance
#   - Establish a resilient-data dashboard with quarterly reporting to the mayor and council; include community input mechanisms to ensure transparency.
#
# Decision triggers
# - If SLR/storm data indicate significantly higher risk than current plan (e.g., >20% higher water levels or higher frequency of severe surge within 5–10 years), accelerate targeted protections and accelerate retreat planning in vulnerable zones.
# - If funding prospects improve (state/federal grants, favorable treasury conditions) and risk-adjusted ROI remains favorable, scale up hybrid protections or accelerate buyouts where equity considerations are strongest.
# - If equity concerns rise due to displacement or loss of housing affordability, pause high-disruption moves and reallocate funds toward protection and affordable replacement housing closer to existing communities.
#
# 6) Top three risks or failure modes and mitigations
# - Risk 1: Underfunding or cost overruns; mitigation: rigorous, staged financing plan; reserve funds; flex in scope; pursue multiple funding streams (bonds, grants, public-private partnerships) and establish a contingency fund. Maintain transparent reporting and public accountability to preserve support.
# - Risk 2: Equity failures and community resistance to retreat; mitigation: invest early in inclusive planning; ensure consent-based buyouts with robust protections; provide strong replacement housing and job opportunities; implement tenant protections and rent subsidies; ensure ongoing community benefits from resilience investments.
# - Risk 3: Maintenance and performance gaps in green infrastructure; mitigation: build local capacity for operations and maintenance; adopt performance-based contracts; require maintenance funds and clear accountability; implement adaptive management to address climate variability.
# - Additional risk: Data uncertainty and political risk; mitigation: decision rules anchored in adaptive management, with defined triggers and rollback options; maintain flexibility to reallocate funds in response to new data or events.
#
# 7) Three prioritized short-term actions (0–5 years) and one pilot project to reduce critical uncertainty
# - Short-term actions (0–5 years)
#   - Action 1: Establish a dedicated resilience governance unit with a clear funding strategy, risk modeling capability, equity-focused design standards, and a detailed data dashboard for ongoing decision-making.
#   - Action 2: Implement 2–3 targeted green infrastructure pilots in high-risk, high-need neighborhoods (e.g., bioswales, permeable pavements, rain gardens, elevated walkways) and upgrade 2–3 critical facilities (schools, clinics, emergency operations) with flood-proofing and backup power. Begin resident outreach on retreat options, and set up a buyout assistance framework.
#   - Action 3: Create a phased, voluntary retreat-readiness plan for the most exposed neighborhoods, including a pilot buyout of a limited number of households, with replacement housing planning, and a local workforce development program to ensure residents can participate in resilience work.
# - Pilot project designed to reduce critical uncertainty
#   - Pilot Project: A 1–2 mile waterfront resilience corridor combining green-blue infrastructure with a modular, low-cost barrier at a critical inlet. This project would be designed as a controlled, data-rich test of:
#     - How green infrastructure reduces flood depth and frequency in a real neighborhood setting,
#     - The incremental cost and performance of low-cost barriers integrated with green systems,
#     - Social acceptability, maintenance needs, and job-creation potential for residents.
#   - Outcomes to measure in the pilot: flood reduction performance, maintenance costs, resident satisfaction, economic impact, and lessons for scaling the approach citywide.
#
# 8) Confidence statement and events that could change the recommendation
# - Confidence level: Medium to High
#   - Rationale: A hybrid approach provides a balanced, adaptable path that mitigates risk from multiple angles, aligns with equity goals, and leverages a broad range of funding opportunities. It also avoids the political and fiscal risks of a single heavy infrastructure push (like a city-wide seawall) or an overly rapid retreat entirely funded by the city.
# - What new evidence or events could most likely change the recommendation:
#   - Funding landscape: If federal/state resilience funding expands significantly or if a major public-private financing mechanism becomes available, a more protective waterfront barrier (or expanded full seawall) could become viable and attractive earlier than planned, potentially shifting more emphasis toward gray infrastructure.
#   - Risk realization: If observed watershed and coastal data indicate a more severe or earlier-than-expected flood regime (e.g., rapid SLR acceleration, higher storm surge frequency), the city might accelerate retreat in certain zones or scale up protection in critical corridors sooner.
#   - Equity and social response: If community engagement reveals widespread opposition to retreat or if displacement risks become politically unsustainable, the plan would need to adjust toward protection and incremental, voluntary retreat with stronger support measures.
#   - Infrastructure performance data: If pilots clearly demonstrate cost-effective flood reduction and scalable maintenance, the city may accelerate green infrastructure deployment and reduce the need for expensive hard barriers.
#
# Notes for executive decision-makers
# - This plan intentionally prioritizes a flexible, equitable, and data-driven approach. It preserves options for scalable protection, prioritizes protecting essential assets, and uses retreat strategically where the risk is highest and the costs are manageable.
# - The equity lens is non-negotiable: protections, housing, and economic opportunities must be accessible to low-income residents who are most exposed.
# - Governance, public engagement, and robust data are essential to keep this plan adaptive and credible to residents, funders, and stakeholders.
#
# If you’d like, I can translate this into a more formal policy memo with a one-page executive summary, a 2–3 page implementation plan for the next 12–18 months, and a high-level budget and financing outline tailored to your city’s specific budgetary and political context.
#
# # Response from competitor 2
#
# **Recommendation:** A hybrid strategy incorporating aspects of options B, C, and D.
#
# **Principal Rationale:**
#
# 1. **Mitigate flood risk while considering long-term resilience**: The hybrid approach will combine the benefits of phased managed retreat with targeted green infrastructure and elevation/flood-proofing measures to protect vulnerable areas. This multi-faceted strategy acknowledges the ongoing threat of sea-level rise and storm surge enhancements while allowing for adaptive management in response to changing conditions.
# 2. **Optimize resource allocation**: By combining elements from each option, the hybrid approach utilizes a mix of short-term (A), mid-term (C), and long-term (B) solutions, ensuring that capital is allocated efficiently across different scales and timeframes.
# 3. **Address distributional impacts and equity concerns**: The hybrid strategy prioritizes inclusive adaptation, incorporating measures designed to support vulnerable populations and ensure equitable outcomes.
#
# **Key Assumptions and Uncertainties:**
#
# 1. Sea-level rise (SLR) projections are reliable (~70% certainty), but some variability exists (20%.
# 2. Projected storm surge intensity and frequency are plausible within current projections (~50% confidence).
# 3. Adaptive management effectiveness in response to changing conditions is uncertain (~30% probability).
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "2"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gpt-5-nano
# Rank 2: llama3.2

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
